# %%
# Dependencies
import requests
import pandas as pd
import pprint as pp
nyt_api = "UaUXnGOcwoVJxZZFpuWJrHyGktUVPe6o"
gbooks_api = "AIzaSyCSagIqpAHzEsb7DXL07Tg1aZzR_Vjpkqg"
#from apikeys import nyt_api, gbooks_api

# %%
# List of encoded NYT bestseller list names
nyt_lists = [
    'combined-print-and-e-book-fiction',
    'hardcover-fiction',
    'mass-market-paperback',
    'e-book-fiction',
    'hardcover-graphic-books',
    'paperback-graphic-books',
    'manga',
    'combined-print-fiction',
    'paperback-books',
    'audio-fiction',
    'graphic-books-and-manga',
]

# Empty list for book information
book_data = []

print("Beginning data retrieval....")

# Loop through NYT bestseller lists
for blist in nyt_lists:
    
    # URL for API call
    url = f"https://api.nytimes.com/svc/books/v3/lists/current/{blist}.json?api-key={nyt_api}"
    
    # Make request and store json response
    try:
        response = requests.get(url).json()
        list_name = response['results']['list_name']
        list_date = response['results']['published_date']

        # Loop through book results in the response
        for book in response['results']['books']:

            # Append book-related information
            book_data.append({
                'Title': book['title'],
                'Author': book['author'],
                'Publisher': book['publisher'],
                'Primary ISBN10': book['primary_isbn10'],
                'Primary ISBN13': book['primary_isbn13'],
                'NYT List': list_name,
                'NYT List Published Date': list_date, 
                'Weeks on NYT List': book['weeks_on_list']
            })
            
    # If bestseller list not found, skip
    except:
        pass
                
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning data retrieval....
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# List of encoded NYT bestseller list names
nyt_lists = [
    'combined-print-and-e-book-fiction',
    'hardcover-fiction',
    'mass-market-paperback',
    'e-book-fiction',
    'hardcover-graphic-books',
    'paperback-graphic-books',
    'manga',
    'combined-print-fiction',
    'paperback-books',
    'audio-fiction',
    'graphic-books-and-manga',
]
sundays_2009 = ["2009-01-04","2009-01-11","2009-01-18"]
#                 "2009-01-26","2009-02-01","2009-02-08",
#                 "2009-02-15","2009-02-22","2009-03-01",
#                 "2009-03-08","2009-03-15","2009-03-29",
#                 "2009-04-05","2009-04-12","2009-04-19",
#                 "2009-04-26","2009-05-03","2009-05-10",
#                 "2009-05-17","2009-05-24","2009-05-31",
#                 "2009-06-07","2009-06-14","2009-06-21",
#                 "2009-06-28","2009-07-05","2009-07-12",
#                 "2009-07-19","2009-07-26","2009-08-02",
#                 "2009-08-09","2009-08-16","2009-08-23",
#                 "2009-08-30","2009-09-06","2009-09-13",
#                 "2009-09-20","2009-09-27","2009-10-04",
#                 "2009-10-11","2009-10-18","2009-10-25",
#                 "2009-11-01","2009-11-08","2009-11-15",
#                 "2009-11-22","2009-11-29","2009-12-06",
#                 "2009-12-13","2009-12-20","2009-12-27"]

# Empty list for book information
book_2009 = []

print("Beginning data retrieval....")

# Loop through NYT bestseller lists
for date in sundays_2009:
    for blist in nyt_lists:
      
            
            
    
    # URL for API call
        url = f"https://api.nytimes.com/svc/books/v3/lists/full-overview.json/get?api-key={nyt_api}"
    
    # Make request and store json response
        try:
            response = requests.get(url).json()
            list_name = response['results']['list_name']
            list_date = response['results']['published_date' == date]

            # Loop through book results in the response
            for book in response['results']['books']:

                # Append book-related information
                book_data.append({
                    'Title': book['title'],
                    'Author': book['author'],
                    'Publisher': book['publisher'],
                    'Primary ISBN10': book['primary_isbn10'],
                    'Primary ISBN13': book['primary_isbn13'],
                    'NYT List': list_name,
                    'NYT List Published Date': list_date, 
                    'Weeks on NYT List': book['weeks_on_list']
                })

        # If bestseller list not found, skip
        except:
            pass
                
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(len(book_data))
# Out:
# Beginning data retrieval....
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 70

# %%
book_df = pd.DataFrame(book_data)
book_df
# Out:
#                                                 Title  \
# 0                                   IT STARTS WITH US
# 1                                LESSONS IN CHEMISTRY
# 2                               DAISY JONES & THE SIX
# 3                                     IT ENDS WITH US
# 4                                           COUNTDOWN
# ..                                                ...
# 65     NATHAN HALE’S HAZARDOUS TALES: ALAMO ALL–STARS
# 66  ROLLING BLACKOUTS: DISPATCHES FROM TURKEY, SYR...
# 67                    STAR WARS: THE ORIGINAL TRILOGY
# 68                         ONE HUNDRED NIGHTS OF HERO
# 69                                       FIGHT CLUB 2
#
#                                     Author          Publisher Primary ISBN10  \
# 0                           Colleen Hoover              Atria     1668001225
# 1                            Bonnie Garmus          Doubleday     038554734X
# 2                      Taylor Jenkins Reid         Ballantine     1524798649
# 3                           Colleen Hoover              Atria     1501110365
# 4       James Patterson and Brendan DuBois      Little, Brown     031645737X
# ..                                     ...                ...            ...
# 65                             Nathan Hale             Abrams     1419719025
# 66                           Sarah Glidden  Drawn & Quarterly     1770462554
# 67  the staff of the Lucas Film Book Group   Disney-Lucasfilm     1484737849
# 68                        Isabel Greenberg      Little, Brown     0316259179
# 69     Chuck Palahniuk and Cameron Stewart         Dark Horse     1616559454
#
#    Primary ISBN13                           NYT List NYT List Published Date  \
# 0   9781668001226  Combined Print and E-Book Fiction              2023-04-09
# 1   9780385547345  Combined Print and E-Book Fiction              2023-04-09
# 2   9781524798642  Combined Print and E-Book Fiction              2023-04-09
# 3   9781501110368  Combined Print and E-Book Fiction              2023-04-09
# 4   9780316457378  Combined Print and E-Book Fiction              2023-04-09
# ..            ...                                ...                     ...
# 65  9781419719028            Hardcover Graphic Books              2017-01-29
# 66  9781770462557            Hardcover Graphic Books              2017-01-29
# 67  9781484737842            Hardcover Graphic Books              2017-01-29
# 68  9780316259170            Hardcover Graphic Books              2017-01-29
# 69  9781616559458            Hardcover Graphic Books              2017-01-29
#
#     Weeks on NYT List
# 0                  23
# 1                  20
# 2                  12
# 3                  93
# 4                   1
# ..                ...
# 65                 32
# 66                  7
# 67                 18
# 68                  3
# 69                 29
#
# [70 rows x 8 columns]

# %%
# Store book information in pandas dataframe
book_df = pd.DataFrame(book_data)
book_df
# Out:
#                                                 Title  \
# 0                                   IT STARTS WITH US
# 1                                LESSONS IN CHEMISTRY
# 2                               DAISY JONES & THE SIX
# 3                                     IT ENDS WITH US
# 4                                           COUNTDOWN
# ..                                                ...
# 65     NATHAN HALE’S HAZARDOUS TALES: ALAMO ALL–STARS
# 66  ROLLING BLACKOUTS: DISPATCHES FROM TURKEY, SYR...
# 67                    STAR WARS: THE ORIGINAL TRILOGY
# 68                         ONE HUNDRED NIGHTS OF HERO
# 69                                       FIGHT CLUB 2
#
#                                     Author          Publisher Primary ISBN10  \
# 0                           Colleen Hoover              Atria     1668001225
# 1                            Bonnie Garmus          Doubleday     038554734X
# 2                      Taylor Jenkins Reid         Ballantine     1524798649
# 3                           Colleen Hoover              Atria     1501110365
# 4       James Patterson and Brendan DuBois      Little, Brown     031645737X
# ..                                     ...                ...            ...
# 65                             Nathan Hale             Abrams     1419719025
# 66                           Sarah Glidden  Drawn & Quarterly     1770462554
# 67  the staff of the Lucas Film Book Group   Disney-Lucasfilm     1484737849
# 68                        Isabel Greenberg      Little, Brown     0316259179
# 69     Chuck Palahniuk and Cameron Stewart         Dark Horse     1616559454
#
#    Primary ISBN13                           NYT List NYT List Published Date  \
# 0   9781668001226  Combined Print and E-Book Fiction              2023-04-09
# 1   9780385547345  Combined Print and E-Book Fiction              2023-04-09
# 2   9781524798642  Combined Print and E-Book Fiction              2023-04-09
# 3   9781501110368  Combined Print and E-Book Fiction              2023-04-09
# 4   9780316457378  Combined Print and E-Book Fiction              2023-04-09
# ..            ...                                ...                     ...
# 65  9781419719028            Hardcover Graphic Books              2017-01-29
# 66  9781770462557            Hardcover Graphic Books              2017-01-29
# 67  9781484737842            Hardcover Graphic Books              2017-01-29
# 68  9780316259170            Hardcover Graphic Books              2017-01-29
# 69  9781616559458            Hardcover Graphic Books              2017-01-29
#
#     Weeks on NYT List
# 0                  23
# 1                  20
# 2                  12
# 3                  93
# 4                   1
# ..                ...
# 65                 32
# 66                  7
# 67                 18
# 68                  3
# 69                 29
#
# [70 rows x 8 columns]

# %%
# Check for duplicates
duplicates = book_df[book_df.duplicated(['Title', 'Author'], keep=False) == True]
duplicates
# Out:
#                                    Title                              Author  \
# 1                   LESSONS IN CHEMISTRY                       Bonnie Garmus
# 4                              COUNTDOWN  James Patterson and Brendan DuBois
# 5                        I WILL FIND YOU                        Harlan Coben
# 6                        HELLO BEAUTIFUL                      Ann Napolitano
# 11                               SMOLDER                 Laurell K. Hamilton
# 12                        THE WHITE LADY                 Jacqueline Winspear
# 14  TOMORROW, AND TOMORROW, AND TOMORROW                     Gabrielle Zevin
# 15                  LESSONS IN CHEMISTRY                       Bonnie Garmus
# 16                       I WILL FIND YOU                        Harlan Coben
# 17                             COUNTDOWN  James Patterson and Brendan DuBois
# 18                       HELLO BEAUTIFUL                      Ann Napolitano
# 19  TOMORROW, AND TOMORROW, AND TOMORROW                     Gabrielle Zevin
# 21                        THE WHITE LADY                 Jacqueline Winspear
# 24                               SMOLDER                 Laurell K. Hamilton
# 33                       A DOG'S PURPOSE                     W Bruce Cameron
# 58                       A DOG'S PURPOSE                     W Bruce Cameron
#
#         Publisher Primary ISBN10 Primary ISBN13  \
# 1       Doubleday     038554734X  9780385547345
# 4   Little, Brown     031645737X  9780316457378
# 5   Grand Central     1538748363  9781538748367
# 6            Dial     0593243730  9780593243732
# 11        Berkley     1984804510  9781984804518
# 12         Harper     0062868004  9780062868008
# 14          Knopf     0593321200  9780593321201
# 15      Doubleday     038554734X  9780385547345
# 16  Grand Central     1538748363  9781538748367
# 17  Little, Brown     031645737X  9780316457378
# 18           Dial     0593243730  9780593243732
# 19          Knopf     0593321200  9780593321201
# 21         Harper     0062867989  9780062867988
# 24        Berkley     1984804499  9781984804495
# 33          Forge     0765388103  9780765388100
# 58          Forge     1429960272  9781429960274
#
#                              NYT List NYT List Published Date  \
# 1   Combined Print and E-Book Fiction              2023-04-09
# 4   Combined Print and E-Book Fiction              2023-04-09
# 5   Combined Print and E-Book Fiction              2023-04-09
# 6   Combined Print and E-Book Fiction              2023-04-09
# 11  Combined Print and E-Book Fiction              2023-04-09
# 12  Combined Print and E-Book Fiction              2023-04-09
# 14  Combined Print and E-Book Fiction              2023-04-09
# 15                  Hardcover Fiction              2023-04-09
# 16                  Hardcover Fiction              2023-04-09
# 17                  Hardcover Fiction              2023-04-09
# 18                  Hardcover Fiction              2023-04-09
# 19                  Hardcover Fiction              2023-04-09
# 21                  Hardcover Fiction              2023-04-09
# 24                  Hardcover Fiction              2023-04-09
# 33              Mass Market Paperback              2017-01-29
# 58                     E-Book Fiction              2017-01-29
#
#     Weeks on NYT List
# 1                  20
# 4                   1
# 5                   2
# 6                   2
# 11                  1
# 12                  1
# 14                 15
# 15                 46
# 16                  2
# 17                  1
# 18                  2
# 19                 26
# 21                  1
# 24                  1
# 33                  6
# 58                  0

# %%
# Pull a specific book from the duplicates list for easier reading
# It looks like books that are both hardcover and audio are responsible for the majority of duplicates   
x = book_df[book_df['Title'] == 'IT STARTS WITH US']
x
# Out:
#                Title          Author Publisher Primary ISBN10 Primary ISBN13  \
# 0  IT STARTS WITH US  Colleen Hoover     Atria     1668001225  9781668001226
#
#                             NYT List NYT List Published Date  \
# 0  Combined Print and E-Book Fiction              2023-04-09
#
#    Weeks on NYT List
# 0                 23

# %%
# Create a new dataframe with duplicates removed
books_clean = book_df.drop_duplicates(subset=['Title', 'Author'], keep='first')
books_clean.reset_index(inplace=True, drop=True)
books_clean
# Out:
#                                                 Title  \
# 0                                   IT STARTS WITH US
# 1                                LESSONS IN CHEMISTRY
# 2                               DAISY JONES & THE SIX
# 3                                     IT ENDS WITH US
# 4                                           COUNTDOWN
# ..                                                ...
# 57     NATHAN HALE’S HAZARDOUS TALES: ALAMO ALL–STARS
# 58  ROLLING BLACKOUTS: DISPATCHES FROM TURKEY, SYR...
# 59                    STAR WARS: THE ORIGINAL TRILOGY
# 60                         ONE HUNDRED NIGHTS OF HERO
# 61                                       FIGHT CLUB 2
#
#                                     Author          Publisher Primary ISBN10  \
# 0                           Colleen Hoover              Atria     1668001225
# 1                            Bonnie Garmus          Doubleday     038554734X
# 2                      Taylor Jenkins Reid         Ballantine     1524798649
# 3                           Colleen Hoover              Atria     1501110365
# 4       James Patterson and Brendan DuBois      Little, Brown     031645737X
# ..                                     ...                ...            ...
# 57                             Nathan Hale             Abrams     1419719025
# 58                           Sarah Glidden  Drawn & Quarterly     1770462554
# 59  the staff of the Lucas Film Book Group   Disney-Lucasfilm     1484737849
# 60                        Isabel Greenberg      Little, Brown     0316259179
# 61     Chuck Palahniuk and Cameron Stewart         Dark Horse     1616559454
#
#    Primary ISBN13                           NYT List NYT List Published Date  \
# 0   9781668001226  Combined Print and E-Book Fiction              2023-04-09
# 1   9780385547345  Combined Print and E-Book Fiction              2023-04-09
# 2   9781524798642  Combined Print and E-Book Fiction              2023-04-09
# 3   9781501110368  Combined Print and E-Book Fiction              2023-04-09
# 4   9780316457378  Combined Print and E-Book Fiction              2023-04-09
# ..            ...                                ...                     ...
# 57  9781419719028            Hardcover Graphic Books              2017-01-29
# 58  9781770462557            Hardcover Graphic Books              2017-01-29
# 59  9781484737842            Hardcover Graphic Books              2017-01-29
# 60  9780316259170            Hardcover Graphic Books              2017-01-29
# 61  9781616559458            Hardcover Graphic Books              2017-01-29
#
#     Weeks on NYT List
# 0                  23
# 1                  20
# 2                  12
# 3                  93
# 4                   1
# ..                ...
# 57                 32
# 58                  7
# 59                 18
# 60                  3
# 61                 29
#
# [62 rows x 8 columns]

# %%
# Copy books_clean (avoids a red warning message) and add columns for Google Book reviews and review count
gbooks_df = books_clean.copy()
gbooks_df['Google Review'] = ''
gbooks_df['Google Review Count'] = ''
gbooks_df
# Out:
#                                                 Title  \
# 0                                   IT STARTS WITH US
# 1                                LESSONS IN CHEMISTRY
# 2                               DAISY JONES & THE SIX
# 3                                     IT ENDS WITH US
# 4                                           COUNTDOWN
# ..                                                ...
# 57     NATHAN HALE’S HAZARDOUS TALES: ALAMO ALL–STARS
# 58  ROLLING BLACKOUTS: DISPATCHES FROM TURKEY, SYR...
# 59                    STAR WARS: THE ORIGINAL TRILOGY
# 60                         ONE HUNDRED NIGHTS OF HERO
# 61                                       FIGHT CLUB 2
#
#                                     Author          Publisher Primary ISBN10  \
# 0                           Colleen Hoover              Atria     1668001225
# 1                            Bonnie Garmus          Doubleday     038554734X
# 2                      Taylor Jenkins Reid         Ballantine     1524798649
# 3                           Colleen Hoover              Atria     1501110365
# 4       James Patterson and Brendan DuBois      Little, Brown     031645737X
# ..                                     ...                ...            ...
# 57                             Nathan Hale             Abrams     1419719025
# 58                           Sarah Glidden  Drawn & Quarterly     1770462554
# 59  the staff of the Lucas Film Book Group   Disney-Lucasfilm     1484737849
# 60                        Isabel Greenberg      Little, Brown     0316259179
# 61     Chuck Palahniuk and Cameron Stewart         Dark Horse     1616559454
#
#    Primary ISBN13                           NYT List NYT List Published Date  \
# 0   9781668001226  Combined Print and E-Book Fiction              2023-04-09
# 1   9780385547345  Combined Print and E-Book Fiction              2023-04-09
# 2   9781524798642  Combined Print and E-Book Fiction              2023-04-09
# 3   9781501110368  Combined Print and E-Book Fiction              2023-04-09
# 4   9780316457378  Combined Print and E-Book Fiction              2023-04-09
# ..            ...                                ...                     ...
# 57  9781419719028            Hardcover Graphic Books              2017-01-29
# 58  9781770462557            Hardcover Graphic Books              2017-01-29
# 59  9781484737842            Hardcover Graphic Books              2017-01-29
# 60  9780316259170            Hardcover Graphic Books              2017-01-29
# 61  9781616559458            Hardcover Graphic Books              2017-01-29
#
#     Weeks on NYT List Google Review Google Review Count
# 0                  23
# 1                  20
# 2                  12
# 3                  93
# 4                   1
# ..                ...           ...                 ...
# 57                 32
# 58                  7
# 59                 18
# 60                  3
# 61                 29
#
# [62 rows x 10 columns]

# %%
# Loop through dataframe
for index, row in gbooks_df.iterrows():
    
    # Search parameter is ISBN13
    isbn = gbooks_df.loc[index,'Primary ISBN13']
    
    # URL for API request
    gurl = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}&key={gbooks_api}"
    
    # Make request
    response = requests.get(gurl).json()

    try:
        
        # Pull rating and rating count from response
        rating = response['items'][0]['volumeInfo']['averageRating']
        review_count = response['items'][0]['volumeInfo']['ratingsCount']

        # Add rating and review count to gbooks dataframe
        gbooks_df.loc[index, 'Average Google Review'] = rating
        gbooks_df.loc[index, 'Google Review Count'] = review_count
    
    # If no average Rating, pass
    except KeyError:
        pass

# %%
gbooks_df
# Out:
#                                                 Title  \
# 0                                   IT STARTS WITH US
# 1                                LESSONS IN CHEMISTRY
# 2                               DAISY JONES & THE SIX
# 3                                     IT ENDS WITH US
# 4                                           COUNTDOWN
# ..                                                ...
# 57     NATHAN HALE’S HAZARDOUS TALES: ALAMO ALL–STARS
# 58  ROLLING BLACKOUTS: DISPATCHES FROM TURKEY, SYR...
# 59                    STAR WARS: THE ORIGINAL TRILOGY
# 60                         ONE HUNDRED NIGHTS OF HERO
# 61                                       FIGHT CLUB 2
#
#                                     Author          Publisher Primary ISBN10  \
# 0                           Colleen Hoover              Atria     1668001225
# 1                            Bonnie Garmus          Doubleday     038554734X
# 2                      Taylor Jenkins Reid         Ballantine     1524798649
# 3                           Colleen Hoover              Atria     1501110365
# 4       James Patterson and Brendan DuBois      Little, Brown     031645737X
# ..                                     ...                ...            ...
# 57                             Nathan Hale             Abrams     1419719025
# 58                           Sarah Glidden  Drawn & Quarterly     1770462554
# 59  the staff of the Lucas Film Book Group   Disney-Lucasfilm     1484737849
# 60                        Isabel Greenberg      Little, Brown     0316259179
# 61     Chuck Palahniuk and Cameron Stewart         Dark Horse     1616559454
#
#    Primary ISBN13                           NYT List NYT List Published Date  \
# 0   9781668001226  Combined Print and E-Book Fiction              2023-04-09
# 1   9780385547345  Combined Print and E-Book Fiction              2023-04-09
# 2   9781524798642  Combined Print and E-Book Fiction              2023-04-09
# 3   9781501110368  Combined Print and E-Book Fiction              2023-04-09
# 4   9780316457378  Combined Print and E-Book Fiction              2023-04-09
# ..            ...                                ...                     ...
# 57  9781419719028            Hardcover Graphic Books              2017-01-29
# 58  9781770462557            Hardcover Graphic Books              2017-01-29
# 59  9781484737842            Hardcover Graphic Books              2017-01-29
# 60  9780316259170            Hardcover Graphic Books              2017-01-29
# 61  9781616559458            Hardcover Graphic Books              2017-01-29
#
#     Weeks on NYT List Google Review Google Review Count
# 0                  23
# 1                  20
# 2                  12
# 3                  93
# 4                   1
# ..                ...           ...                 ...
# 57                 32
# 58                  7
# 59                 18
# 60                  3
# 61                 29
#
# [62 rows x 10 columns]

# %%
sundays_2009 = ["2009-01-04","2009-01-11","2009-01-18","2009-01-26","2009-02-01","2009-02-08","2009-02-15","2009-02-22","2009-03-01","2009-03-08","2009-03-15","2009-03-29","2009-04-05","2009-04-12","2009-04-19","2009-04-26","2009-05-03","2009-05-10","2009-05-17","2009-05-24","2009-05-31","2009-06-07","2009-06-14","2009-06-21","2009-06-28","2009-07-05","2009-07-12","2009-07-19","2009-07-26","2009-08-02","2009-08-09","2009-08-16","2009-08-23","2009-08-30","2009-09-06","2009-09-13","2009-09-20","2009-09-27","2009-10-04","2009-10-11","2009-10-18","2009-10-25","2009-11-01","2009-11-08","2009-11-15","2009-11-22","2009-11-29","2009-12-06","2009-12-13","2009-12-20","2009-12-27"]

# %%
https://api.nytimes.com/svc/books/v3/lists/full-overview.json/get
